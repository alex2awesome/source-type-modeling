# %%
import glob
import os
import tarfile
from bs4 import BeautifulSoup
import pandas as pd 
from tqdm.auto import tqdm
import shutil
import codecs

# %%
for year_folder in tqdm(glob.glob('../data/nyt-ldc/nyt_corpus/data/*')):
    article_chunks = []
    
    ## clean up if last round failed...
    for last_run in filter(lambda x: '.tgz' not in x, glob.glob(os.path.join(year_folder, '*'))):
        shutil.rmtree(last_run)
    
    ## iterate through each month
    for month_tgz in glob.glob(os.path.join(year_folder, '*')):
        ## untar folder
        tar = tarfile.open(name=month_tgz, mode="r:gz")
        tar.extractall(path=year_folder)

        ## extract data from XML files
        day_xml_files = glob.glob(os.path.join(month_tgz.replace('.tgz', ''), '*', '*') + '.xml')

        ## read through each article
        for xml_file in day_xml_files:
            content = codecs.open(xml_file, encoding='utf-8').read()
            soup = BeautifulSoup(content, features="xml")

            ## parse HTML 
            article_chunk = {}
            for metadata in soup.find_all('meta'):
                name = metadata['name']
                cont = metadata['content']
                article_chunk[name] = cont
            
            if soup.find('hedline'):
                article_chunk['headline'] = soup.find('hedline').get_text()
            article_chunk['body'] = soup.find('body.content').get_text()

            article_chunks.append(article_chunk)

        ## clean up
        shutil.rmtree(month_tgz.replace('.tgz', ''))
        
    ## dump contents
    year_name = os.path.basename(year_folder)
    year_csv_fname = os.path.join('../data/nyt-ldc/nyt_corpus/csvs/', year_name) + '.csv'
    pd.DataFrame(article_chunks).to_csv(year_csv_fname)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# # Look at Data

# %%
import glob

# %%
csv_files = glob.glob('../data/nyt-ldc/nyt_corpus/*')

# %%
all_data = []
for f in tqdm(csv_files):
    data_df = pd.read_csv(f, index_col=0)
    data_df = (
        data_df
            .loc[lambda df: df['body'].notnull()]
            .loc[lambda df: ~df['body'].str.contains('COMPANY REPORTS')]
    )
    
    data_df['body'] = (
        data_df['body']
         .str.strip()
         .str.split('\n')
         .apply(lambda x: list(filter(lambda y: not y.startswith('LEAD:'), x)))
         .apply(lambda x: list(filter(lambda y: y.strip() != '', x)))
         .str.join('\n')
    )
    all_data.append(data_df)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_15002/2903379504.py:3: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(f, index_col=0)
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_15002/2903379504.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(f, index_col=0)
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_15002/2903379504.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(f, index_col=0)
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_15002/2903379504.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(f, index_col=0)
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_15002/2903379504.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(f, index_col=0)
# /var/folders/xh/qnyq7yzj0r328_7hnb7pgxth0000gp/T/ipykernel_15002/2903379504.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(f, index_col=0)

# %%
all_data_df = pd.concat(all_data)
all_data_df = (all_data_df
                   .loc[lambda df: df['online_sections'].notnull()]
                   .loc[lambda df: ~df['online_sections'].str.contains('Paid Death Notices')]
                   .loc[lambda df: ~df['online_sections'].str.contains('Corrections')]               
              )
all_data_df = all_data_df.loc[lambda df: ~df['headline'].str.strip().str.lower().isin(headlines_to_exclude)]
all_data_df = (
    all_data_df
         .loc[lambda df: df['body'].str.len() > 3_500]
         .loc[lambda df: df['body'].str.len() < 10_000]
)

# %%
import string
import re

# %%
def replace_punct(s, include_space=False):
    for p in string.punctuation:
        if include_space:
            s = s.replace(p, ' ')
        else:
            s = s.replace(p, '')
    return s
    
def make_id(x):
    ## make section
    section = x['dsk']
    if pd.isnull(section):
        section = 'other'
    else:
        section = replace_punct(section, include_space=True).lower().strip().split()[0]

    ## make headline slug
    headline = x['headline']
    if pd.isnull(headline):
        headline = 'no-headline'
    else:
        headline = replace_punct(headline, include_space=True)
        headline = re.sub('\s+', ' ', headline)
        headline = '-'.join(headline.split()[:8]).lower()

    year = str(int(x['publication_year'])).zfill(4)
    month = str(int(x['publication_month'])).zfill(2)
    day = str(int(x['publication_day_of_month'])).zfill(2)
    return f"{year}/{month}/{day}/{section}/{headline}"

# %%
all_data_df['id'] = all_data_df.apply(make_id, axis=1)

# %%
all_data_df.to_csv('../data/nyt-ldc/nyt-ldc-docs-to-score.csv.gz', compression='gzip')

# %%
all_data_df.head()
# Out:
#     publication_day_of_month  publication_month  publication_year  \
# 10                       3.0                2.0            1990.0
# 11                       3.0                2.0            1990.0
# 13                       3.0                2.0            1990.0
# 18                       3.0                2.0            1990.0
# 21                       3.0                2.0            1990.0
#
#    publication_day_of_week                dsk  print_page_number  \
# 10                Saturday         Style Desk               35.0
# 11                Saturday  Metropolitan Desk               31.0
# 13                Saturday         Style Desk               35.0
# 18                Saturday       Foreign Desk                3.0
# 21                Saturday        Sports Desk               49.0
#
#    print_section  print_column      online_sections  \
# 10             1           1.0                Style
# 11             1           1.0  New York and Region
# 13             1           4.0                Style
# 18             1           1.0                World
# 21             1           1.0               Sports
#
#                                              headline  \
# 10  \nCONSUMER'S WORLD: Coping;   With Tired Bathr...
# 11  \nDinkins Names 6 Officials, Including Head of...
# 13  \nCar Makers Fight to Reclaim Market in Replac...
# 18  \nPinochet Gets Role in Inauguration of New Le...
# 21              \nOne on One With Magic And Michael\n
#
#                                                  body banner correction_date  \
# 10  Your 1950's bathroom is showing its age. It lo...    NaN             NaN
# 11  Mayor David N. Dinkins said yesterday that he ...    NaN             NaN
# 13  An embattled automobile industry is mounting a...    NaN             NaN
# 18  After initially seeking ways to avoid taking p...    NaN             NaN
# 21  A one-on-one basketball game between Magic Joh...    NaN             NaN
#
#    series_name slug feature_page column_name alternate_url  \
# 10         NaN  NaN          NaN         NaN           NaN
# 11         NaN  NaN          NaN         NaN           NaN
# 13         NaN  NaN          NaN         NaN           NaN
# 18         NaN  NaN          NaN         NaN           NaN
# 21         NaN  NaN          NaN         NaN           NaN
#
#                                                    id
# 10  1990/02/03/style/consumer-s-world-coping-with-...
# 11  1990/02/03/metropolitan/dinkins-names-6-offici...
# 13  1990/02/03/style/car-makers-fight-to-reclaim-m...
# 18  1990/02/03/foreign/pinochet-gets-role-in-inaug...
# 21  1990/02/03/sports/one-on-one-with-magic-and-mi...

# %%
pd.read_csv('../data/nyt-ldc/nyt-ldc-docs-to-score.csv.gz', skiprows=range(1,1), nrows=10)
# Out:
#    Unnamed: 0  publication_day_of_month  publication_month  publication_year  \
# 0          10                       3.0                2.0            1990.0
# 1          11                       3.0                2.0            1990.0
# 2          13                       3.0                2.0            1990.0
# 3          18                       3.0                2.0            1990.0
# 4          21                       3.0                2.0            1990.0
# 5          49                       3.0                2.0            1990.0
# 6          56                       3.0                2.0            1990.0
# 7          57                       3.0                2.0            1990.0
# 8          64                       3.0                2.0            1990.0
# 9          65                       3.0                2.0            1990.0
#
#   publication_day_of_week                dsk  print_page_number  \
# 0                Saturday         Style Desk               35.0
# 1                Saturday  Metropolitan Desk               31.0
# 2                Saturday         Style Desk               35.0
# 3                Saturday       Foreign Desk                3.0
# 4                Saturday        Sports Desk               49.0
# 5                Saturday     Financial Desk               38.0
# 6                Saturday     Financial Desk                1.0
# 7                Saturday  Metropolitan Desk               29.0
# 8                Saturday      National Desk               11.0
# 9                Saturday  Metropolitan Desk               29.0
#
#    print_section  print_column              online_sections  \
# 0              1           1.0                        Style
# 1              1           1.0          New York and Region
# 2              1           4.0                        Style
# 3              1           1.0                        World
# 4              1           1.0                       Sports
# 5              1           1.0                     Business
# 6              1           2.0                     Business
# 7              1           5.0  Health; New York and Region
# 8              1           1.0                         U.S.
# 9              1           2.0          New York and Region
#
#                                             headline  \
# 0  \nCONSUMER'S WORLD: Coping;   With Tired Bathr...
# 1  \nDinkins Names 6 Officials, Including Head of...
# 2  \nCar Makers Fight to Reclaim Market in Replac...
# 3  \nPinochet Gets Role in Inauguration of New Le...
# 4              \nOne on One With Magic And Michael\n
# 5       \nYour Money;   Planning Now For '90 Taxes\n
# 6  \nCompany News;   U.S. Biotechnology Leader to...
# 7  \nCUNY Panel Says Doctors Fail to Serve As Pro...
# 8             \nFight On Cleanup Of Harbor Goes On\n
# 9  \nSurprise Witness for Gotti: Victim of the '8...
#
#                                                 body  banner  correction_date  \
# 0  Your 1950's bathroom is showing its age. It lo...     NaN              NaN
# 1  Mayor David N. Dinkins said yesterday that he ...     NaN              NaN
# 2  An embattled automobile industry is mounting a...     NaN              NaN
# 3  After initially seeking ways to avoid taking p...     NaN              NaN
# 4  A one-on-one basketball game between Magic Joh...     NaN              NaN
# 5  As taxpayers go over their financial records i...     NaN              NaN
# 6  Genentech Inc., the crown jewel of the United ...     NaN              NaN
# 7  City College opened the Sophie Davis School of...     NaN              NaN
# 8  Long after the last vote was counted in the 19...     NaN              NaN
# 9  A former union official who prosecutors say wa...     NaN              NaN
#
#    series_name  slug  feature_page  column_name  alternate_url
# 0          NaN   NaN           NaN          NaN            NaN
# 1          NaN   NaN           NaN          NaN            NaN
# 2          NaN   NaN           NaN          NaN            NaN
# 3          NaN   NaN           NaN          NaN            NaN
# 4          NaN   NaN           NaN          NaN            NaN
# 5          NaN   NaN           NaN          NaN            NaN
# 6          NaN   NaN           NaN          NaN            NaN
# 7          NaN   NaN           NaN          NaN            NaN
# 8          NaN   NaN           NaN          NaN            NaN
# 9          NaN   NaN           NaN          NaN            NaN
